# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import numpy as np

x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

data = list(zip(x, y))

aglo = AgglomerativeClustering(n_clusters=5, affinity="euclidean", linkage="ward")
labels = aglo.fit_predict(data)
print(labels)
plt.scatter(x, y, c=labels, cmap='viridis', marker='*', s=80)
plt.show()
# Out:
# [0 0 3 2 2 3 4 0 1 1]
# C:\Users\Fiza\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
